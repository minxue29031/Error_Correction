# %%
import os
import subprocess

# Change working directory to git repository root directory
result = subprocess.run(['git', 'rev-parse', '--show-toplevel'], stdout=subprocess.PIPE)
root_dir = result.stdout.decode('utf-8').replace('\n', '')
os.chdir(root_dir)

# %%
import numpy as np

from codegen_sources.model.translate import Translator
from codegen_sources.scripts.knnmt.load_functions import extract_functions, load_validation_functions
from codegen_sources.scripts.knnmt.knnmt import KNNMT

try:
    from codegen_sources.scripts.knnmt.datastore import add_to_datastore, train_datastore
except ImportError:
    pass
# Out:
# adding to path /pfs/data5/home/hd/hd_hd/hd_tf268/code-gen

# %%
DATASET_PATH = "data/test_dataset"

# %%
def output_sample(knnmt: KNNMT, translator: Translator, language_pair: str, data_index: int):
    src_language, tgt_language = language_pair.split("_")[0], language_pair.split("_")[1]

    # Get tokenized source function
    source_functions = extract_functions(f"{DATASET_PATH}/transcoder_test.{src_language}.tok")
    source = source_functions[data_index]
    source = translator.tokenize(source, src_language)
    generated = ""
    inputs = ""
    tc_prediction = ""

    # Predict target tokens using kNN-MT only
    while "</s>" not in generated and len(generated.split(" ")) < 200:
        tc_target, prediction, input = predict_next_token(knnmt, translator, src_language, tgt_language, source, generated)
        generated += " " + prediction
        inputs += f"{input[0]}\n{input[1]}\n"
        tc_prediction += " " + tc_target

    # Get original TransCoder translation
    translation = translator.translate(source, src_language, tgt_language)[0]
    translator.use_knn_store = False
    original_translation = translator.translate(source, src_language, tgt_language)[0]
    
    target_functions = extract_functions(f"{DATASET_PATH}/transcoder_test.{tgt_language}.tok")
    target = target_functions[data_index]
    target = translator.tokenize(target, tgt_language)
    
    print("\n\n\n\n\n")
    print(f"TC PREDICTION: '{tc_prediction[1:]}'")
    print(f"FINAL PREDICTION: '{generated[1:]}'")
    print(f"GROUND TRUTH: '{target} </s>'")
    print("\n\n")

# %%
def predict_next_token(
    knnmt: KNNMT,
    translator: Translator,
    src_language: str,
    tgt_language: str,
    source: str,
    generated: str
):
    # Get hidden feature representation of last decoder layer and ground truth target tokens
    decoder_features, _, targets, target_tokens, _, _ = translator.get_features(
        input_code=source,
        target_code=generated,
        src_language=src_language,
        tgt_language=tgt_language,
        predict_single_token=True,
        tokenized=True
    )

    # Retrieve k nearest neighbors including their distances and inputs
    language_pair = f"{src_language}_{tgt_language}"
    features = decoder_features[-1].unsqueeze(0)
    knns, distances, inputs = knnmt.get_k_nearest_neighbors(features, language_pair, with_inputs=True)
    tokens = [translator.get_token(id) for id in knns[0]]
    
    print("\n\n\n\n\n")
    print("=" * 100)
    print(f"SOURCE: '{source}'")
    print(f"GENERATED: '{generated[1:]}'\n")
    print("-" * 100)
    print(f"\nNEXT TC TARGET: '{target_tokens[-1]}'")
    print(f"PREDICTIONS: {tokens}")
    print(f"DISTANCES: {distances[0].astype(int)}\n")
    print("-" * 100)
    print(f"\nINPUT SOURCE: '{inputs[0][0][0][5:]}'")
    print(f"INPUT TARGET: '{inputs[0][0][1]}'")
    print("=" * 100)

    # import pdb; pdb.set_trace()
    return target_tokens[-1], tokens[0], inputs[0][0]

# %%
knnmt = KNNMT("out/knnmt/one_click_demo")

if not os.path.exists("out/knnmt/one_click_demo"):
    validation_functions = load_functions.load_validation_functions("data/test_dataset", language_pair="cpp_java")
    add_to_datastore(knnmt, { "cpp_java": validation_functions }, is_validation=True)
    train_datastore(knnmt, language_pair="cpp_java")

# %%
language_pair = "cpp_java"
src_language = language_pair.split("_")[0]
tgt_language = language_pair.split("_")[1]

translator_path = f"models/Online_ST_{src_language.title()}_{tgt_language.title()}.pth".replace("Cpp", "CPP")
translator = Translator(
    translator_path,
    "data/bpe/cpp-java-python/codes",
    global_model=True,
    knnmt_dir=knnmt.knnmt_dir
)

output_sample(knnmt, translator, language_pair, 442)
# Out:
# INFO - 10/23/22 20:51:09 - 0:00:05 - ============ Model Reloading
# INFO - 10/23/22 20:51:09 - 0:00:05 - Reloading encoder from models/Online_ST_CPP_Java.pth ...
# WARNING - 10/23/22 20:51:14 - 0:00:09 - Lang cpp_sa matched to pretrained cpp_sa lang embedding.
# WARNING - 10/23/22 20:51:14 - 0:00:09 - Lang java_sa matched to pretrained java_sa lang embedding.
# WARNING - 10/23/22 20:51:14 - 0:00:09 - Lang python_sa matched to pretrained python_sa lang embedding.
# INFO - 10/23/22 20:51:15 - 0:00:10 - Reloading decoders from models/Online_ST_CPP_Java.pth ...
# WARNING - 10/23/22 20:51:16 - 0:00:11 - Lang cpp_sa matched to pretrained cpp_sa lang embedding.
# WARNING - 10/23/22 20:51:16 - 0:00:11 - Lang java_sa matched to pretrained java_sa lang embedding.
# WARNING - 10/23/22 20:51:16 - 0:00:11 - Lang python_sa matched to pretrained python_sa lang embedding.
# INFO - 10/23/22 20:51:16 - 0:00:12 - Number of parameters (encoder): 143279616
# INFO - 10/23/22 20:51:16 - 0:00:12 - Number of parameters (decoders): 168482304
# INFO - 10/23/22 20:51:16 - 0:00:12 - Number of decoders: 1
#
# Loading codes from /pfs/data5/home/hd/hd_hd/hd_tf268/code-gen/data/bpe/cpp-java-python/codes ...
# Read 50000 codes from the codes file.
# Loading Faiss Index for 'cpp_java'
# Loading Datastore Values for 'cpp_java'
# Values:  (61823,)
# Loading Datastore Inputs for 'cpp_java'
# Values:  (61823, 2)
#
#
#
#
#
#
# ====================================================================================================
# SOURCE: 'bool is@@ Even ( int n ) { return ( ! ( n & 1 ) ) ; }'
# GENERATED: ''
#
# ----------------------------------------------------------------------------------------------------
#
# NEXT TC TARGET: 'public'
# PREDICTIONS: ['static', 'static', 'static', 'public', 'static']
# DISTANCES: [103 107 107 110 113]
#
# ----------------------------------------------------------------------------------------------------
#
# INPUT SOURCE: 'bool is@@ Prime ( int n ) { if ( n <= 1 ) return false ; for ( int i = 2 ; i < n ; i ++ ) if ( n % i == 0 ) return false ; return true ; } </s>'
# INPUT TARGET: ''
# ====================================================================================================
#
#
#
#
#
#
# ====================================================================================================
# SOURCE: 'bool is@@ Even ( int n ) { return ( ! ( n & 1 ) ) ; }'
# GENERATED: 'static'
#
# ----------------------------------------------------------------------------------------------------
#
# NEXT TC TARGET: 'boolean'
# PREDICTIONS: ['boolean', 'boolean', 'boolean', 'boolean', 'boolean']
# DISTANCES: [193 197 201 201 201]
#
# ----------------------------------------------------------------------------------------------------
#
# INPUT SOURCE: 'bool is@@ Prime ( int n ) { if ( n <= 1 ) return false ; for ( int i = 2 ; i < n ; i ++ ) if ( n % i == 0 ) return false ; return true ; } </s>'
# INPUT TARGET: 'static'
# ====================================================================================================
#
#
#
#
#
#
# ====================================================================================================
# SOURCE: 'bool is@@ Even ( int n ) { return ( ! ( n & 1 ) ) ; }'
# GENERATED: 'static boolean'
#
# ----------------------------------------------------------------------------------------------------
#
# NEXT TC TARGET: 'is@@'
# PREDICTIONS: ['is@@', 'is@@', 'is@@', 'is@@', 'is@@']
# DISTANCES: [598 603 611 615 628]
#
# ----------------------------------------------------------------------------------------------------
#
# INPUT SOURCE: 'bool is@@ Conver@@ tible ( string str1 , string str2 , int k ) { if ( ( str1 . length ( ) + str2 . length ( ) ) < k ) return true ; int common@@ Length = 0 ; for ( int i = 0 ; i < min ( str1 . length ( ) , str2 . length ( ) ) ; i ++ ) { if ( str1 [ i ] == str2 [ i ] ) common@@ Length ++ ; else break ; } if ( ( k - str1 . length ( ) - str2 . length ( ) + 2 * common@@ Length ) % 2 == 0 ) return true ; return false ; } </s>'
# INPUT TARGET: 'static boolean'
# ====================================================================================================
#
#
#
#
#
#
# ====================================================================================================
# SOURCE: 'bool is@@ Even ( int n ) { return ( ! ( n & 1 ) ) ; }'
# GENERATED: 'static boolean is@@'
#
# ----------------------------------------------------------------------------------------------------
#
# NEXT TC TARGET: 'Even'
# PREDICTIONS: ['Even', 'Prime', 'Sparse', 'Composite', 'Even']
# DISTANCES: [ 937 1065 1185 1193 1196]
#
# ----------------------------------------------------------------------------------------------------
#
# INPUT SOURCE: 'string decode@@ Median@@ String ( string s ) { int l = s . length ( ) ; string s1 = " ▁ " ; bool is@@ Even = ( l % 2 == 0 ) ? true : false ; for ( int i = 0 ; i < l ; i += 2 ) { if ( is@@ Even ) { s1 = s [ i ] + s1 ; s1 += s [ i + 1 ] ; } else { if ( l - i > 1 ) { s1 += s [ i ] ; s1 = s [ i + 1 ] + s1 ; } else { s1 += s [ i ] ; } } } return s1 ; } </s>'
# INPUT TARGET: 'static String decode@@ Median@@ String ( String s ) { int l = s . length ( ) ; String s1 = " ▁ " ; boolean is@@'
# ====================================================================================================
#
#
#
#
#
#
# ====================================================================================================
# SOURCE: 'bool is@@ Even ( int n ) { return ( ! ( n & 1 ) ) ; }'
# GENERATED: 'static boolean is@@ Even'
#
# ----------------------------------------------------------------------------------------------------
#
# NEXT TC TARGET: '('
# PREDICTIONS: ['(', '(', '(', '(', '(']
# DISTANCES: [618 714 762 768 781]
#
# ----------------------------------------------------------------------------------------------------
#
# INPUT SOURCE: 'bool is@@ Prime ( int n ) { if ( n <= 1 ) return false ; for ( int i = 2 ; i < n ; i ++ ) if ( n % i == 0 ) return false ; return true ; } </s>'
# INPUT TARGET: 'static boolean is@@ Prime'
# ====================================================================================================
#
#
#
#
#
#
# ====================================================================================================
# SOURCE: 'bool is@@ Even ( int n ) { return ( ! ( n & 1 ) ) ; }'
# GENERATED: 'static boolean is@@ Even ('
#
# ----------------------------------------------------------------------------------------------------
#
# NEXT TC TARGET: 'int'
# PREDICTIONS: ['int', 'int', 'int', 'int', 'int']
# DISTANCES: [351 352 379 393 398]
#
# ----------------------------------------------------------------------------------------------------
#
# INPUT SOURCE: 'bool is@@ Composite ( int n ) { if ( n <= 1 ) return false ; if ( n <= 3 ) return false ; if ( n % 2 == 0 || n % 3 == 0 ) return true ; for ( int i = 5 ; i * i <= n ; i = i + 6 ) if ( n % i == 0 || n % ( i + 2 ) == 0 ) return true ; return false ; } </s>'
# INPUT TARGET: 'static boolean is@@ Composite ('
# ====================================================================================================
#
#
#
#
#
#
# ====================================================================================================
# SOURCE: 'bool is@@ Even ( int n ) { return ( ! ( n & 1 ) ) ; }'
# GENERATED: 'static boolean is@@ Even ( int'
#
# ----------------------------------------------------------------------------------------------------
#
# NEXT TC TARGET: 'n'
# PREDICTIONS: ['n', 'n', 'n', 'n', 'n']
# DISTANCES: [354 384 389 395 396]
#
# ----------------------------------------------------------------------------------------------------
#
# INPUT SOURCE: 'bool get@@ Par@@ ity ( unsigned int n ) { bool parity = 0 ; while ( n ) { parity = ! parity ; n = n & ( n - 1 ) ; } return parity ; } </s>'
# INPUT TARGET: 'static boolean get@@ Par@@ ity ( int'
# ====================================================================================================
#
#
#
#
#
#
# ====================================================================================================
# SOURCE: 'bool is@@ Even ( int n ) { return ( ! ( n & 1 ) ) ; }'
# GENERATED: 'static boolean is@@ Even ( int n'
#
# ----------------------------------------------------------------------------------------------------
#
# NEXT TC TARGET: ')'
# PREDICTIONS: [')', ')', ')', ')', ')']
# DISTANCES: [314 338 345 346 347]
#
# ----------------------------------------------------------------------------------------------------
#
# INPUT SOURCE: 'bool is@@ Composite ( int n ) { if ( n <= 1 ) return false ; if ( n <= 3 ) return false ; if ( n % 2 == 0 || n % 3 == 0 ) return true ; for ( int i = 5 ; i * i <= n ; i = i + 6 ) if ( n % i == 0 || n % ( i + 2 ) == 0 ) return true ; return false ; } </s>'
# INPUT TARGET: 'static boolean is@@ Composite ( int n'
# ====================================================================================================
#
#
#
#
#
#
# ====================================================================================================
# SOURCE: 'bool is@@ Even ( int n ) { return ( ! ( n & 1 ) ) ; }'
# GENERATED: 'static boolean is@@ Even ( int n )'
#
# ----------------------------------------------------------------------------------------------------
#
# NEXT TC TARGET: '{'
# PREDICTIONS: ['{', '{', '{', '{', '{']
# DISTANCES: [189 190 190 191 191]
#
# ----------------------------------------------------------------------------------------------------
#
# INPUT SOURCE: 'public : int sum@@ Digits ( int no ) { return no == 0 ? 0 : no % 10 + sum@@ Digits ( no / 10 ) ; } </s>'
# INPUT TARGET: 'static int sum@@ Digits ( int no )'
# ====================================================================================================
#
#
#
#
#
#
# ====================================================================================================
# SOURCE: 'bool is@@ Even ( int n ) { return ( ! ( n & 1 ) ) ; }'
# GENERATED: 'static boolean is@@ Even ( int n ) {'
#
# ----------------------------------------------------------------------------------------------------
#
# NEXT TC TARGET: 'return'
# PREDICTIONS: ['return', 'return', 'return', 'return', 'return']
# DISTANCES: [386 404 411 411 419]
#
# ----------------------------------------------------------------------------------------------------
#
# INPUT SOURCE: 'bool check@@ Origin ( int x1 , int y1 , int x2 , int y2 ) { return ( x1 * ( y2 - y1 ) == y1 * ( x2 - x1 ) ) ; } </s>'
# INPUT TARGET: 'static boolean check@@ Origin ( int x1 , int y1 , int x2 , int y2 ) {'
# ====================================================================================================
#
#
#
#
#
#
# ====================================================================================================
# SOURCE: 'bool is@@ Even ( int n ) { return ( ! ( n & 1 ) ) ; }'
# GENERATED: 'static boolean is@@ Even ( int n ) { return'
#
# ----------------------------------------------------------------------------------------------------
#
# NEXT TC TARGET: '('
# PREDICTIONS: ['(', '(', '(', '(', '(']
# DISTANCES: [521 554 555 567 567]
#
# ----------------------------------------------------------------------------------------------------
#
# INPUT SOURCE: 'bool is@@ Possible@@ To@@ Make@@ Di@@ visible ( int arr [ ] , int n ) { int remainder = 0 ; for ( int i = 0 ; i < n ; i ++ ) remainder = ( remainder + arr [ i ] ) % 3 ; return ( remainder == 0 ) ; } </s>'
# INPUT TARGET: 'public static boolean is@@ Possible@@ To@@ Make@@ Di@@ visible ( int arr [ ] , int n ) { int remainder = 0 ; for ( int i = 0 ; i < n ; i ++ ) remainder = ( remainder + arr [ i ] ) % 3 ; return'
# ====================================================================================================
#
#
#
#
#
#
# ====================================================================================================
# SOURCE: 'bool is@@ Even ( int n ) { return ( ! ( n & 1 ) ) ; }'
# GENERATED: 'static boolean is@@ Even ( int n ) { return ('
#
# ----------------------------------------------------------------------------------------------------
#
# NEXT TC TARGET: '!'
# PREDICTIONS: ['(', '(', '!', '!', 'dp']
# DISTANCES: [604 633 746 750 753]
#
# ----------------------------------------------------------------------------------------------------
#
# INPUT SOURCE: 'unsigned int next@@ PowerOf@@ 2 ( unsigned int n ) { unsigned count = 0 ; if ( n && ! ( n & ( n - 1 ) ) ) return n ; while ( n != 0 ) { n >>= 1 ; count += 1 ; } return 1 << count ; } </s>'
# INPUT TARGET: 'static int next@@ PowerOf@@ 2 ( int n ) { int count = 0 ; if ( n > 0 &&'
# ====================================================================================================
#
#
#
#
#
#
# ====================================================================================================
# SOURCE: 'bool is@@ Even ( int n ) { return ( ! ( n & 1 ) ) ; }'
# GENERATED: 'static boolean is@@ Even ( int n ) { return ( ('
#
# ----------------------------------------------------------------------------------------------------
#
# NEXT TC TARGET: 'n'
# PREDICTIONS: ['n', 'n', 'n', 'n', 'n']
# DISTANCES: [555 656 703 719 727]
#
# ----------------------------------------------------------------------------------------------------
#
# INPUT SOURCE: 'unsigned int next@@ PowerOf@@ 2 ( unsigned int n ) { unsigned count = 0 ; if ( n && ! ( n & ( n - 1 ) ) ) return n ; while ( n != 0 ) { n >>= 1 ; count += 1 ; } return 1 << count ; } </s>'
# INPUT TARGET: 'static int next@@ PowerOf@@ 2 ( int n ) { int count = 0 ; if ( n > 0 && ('
# ====================================================================================================
#
#
#
#
#
#
# ====================================================================================================
# SOURCE: 'bool is@@ Even ( int n ) { return ( ! ( n & 1 ) ) ; }'
# GENERATED: 'static boolean is@@ Even ( int n ) { return ( ( n'
#
# ----------------------------------------------------------------------------------------------------
#
# NEXT TC TARGET: '&'
# PREDICTIONS: ['&', '&', '&', '&', '&']
# DISTANCES: [424 462 504 512 542]
#
# ----------------------------------------------------------------------------------------------------
#
# INPUT SOURCE: 'int Position@@ Right@@ most@@ Set@@ bit ( int n ) { int position = 1 ; int m = 1 ; while ( ! ( n & m ) ) { m = m << 1 ; position ++ ; } return position ; } </s>'
# INPUT TARGET: 'static int Position@@ Right@@ most@@ Set@@ bit ( int n ) { int position = 1 ; int m = 1 ; while ( ( n'
# ====================================================================================================
#
#
#
#
#
#
# ====================================================================================================
# SOURCE: 'bool is@@ Even ( int n ) { return ( ! ( n & 1 ) ) ; }'
# GENERATED: 'static boolean is@@ Even ( int n ) { return ( ( n &'
#
# ----------------------------------------------------------------------------------------------------
#
# NEXT TC TARGET: '1'
# PREDICTIONS: ['1', '1', '1', '1', '1']
# DISTANCES: [669 714 719 726 750]
#
# ----------------------------------------------------------------------------------------------------
#
# INPUT SOURCE: 'void n@@ th@@ Pal@@ ind@@ ro@@ me ( int n , int k ) { int temp = ( k & 1 ) ? ( k / 2 ) : ( k / 2 - 1 ) ; int pal@@ ind@@ ro@@ me = ( int ) pow ( 10 , temp ) ; pal@@ ind@@ ro@@ me += n - 1 ; printf ( " ▁ % ▁ d ▁ " , pal@@ ind@@ ro@@ me ) ; if ( k & 1 ) pal@@ ind@@ ro@@ me /= 10 ; while ( pal@@ ind@@ ro@@ me ) { printf ( " ▁ % ▁ d ▁ " , pal@@ ind@@ ro@@ me % 10 ) ; pal@@ ind@@ ro@@ me /= 10 ; } printf ( " ▁ \n ▁ " ) ; } </s>'
# INPUT TARGET: 'static void n@@ th@@ Pal@@ ind@@ ro@@ me ( int n , int k ) { int temp = ( k &'
# ====================================================================================================
#
#
#
#
#
#
# ====================================================================================================
# SOURCE: 'bool is@@ Even ( int n ) { return ( ! ( n & 1 ) ) ; }'
# GENERATED: 'static boolean is@@ Even ( int n ) { return ( ( n & 1'
#
# ----------------------------------------------------------------------------------------------------
#
# NEXT TC TARGET: ')'
# PREDICTIONS: [')', ')', ')', ')', ')']
# DISTANCES: [703 718 732 786 826]
#
# ----------------------------------------------------------------------------------------------------
#
# INPUT SOURCE: 'bool can@@ Form@@ Pal@@ ind@@ ro@@ me ( string str ) { int count [ NO_@@ OF_@@ CHARS ] = { 0 } ; for ( int i = 0 ; str [ i ] ; i ++ ) count [ str [ i ] ] ++ ; int odd = 0 ; for ( int i = 0 ; i < NO_@@ OF_@@ CHARS ; i ++ ) { if ( count [ i ] & 1 ) odd ++ ; if ( odd > 1 ) return false ; } return true ; } </s>'
# INPUT TARGET: 'static boolean can@@ Form@@ Pal@@ ind@@ ro@@ me ( String str ) { int count [ ] = new int [ NO_@@ OF_@@ CHARS ] ; Arrays . fill ( count , 0 ) ; for ( int i = 0 ; i < str . length ( ) ; i ++ ) count [ ( int ) ( str . charAt ( i ) ) ] ++ ; int odd = 0 ; for ( int i = 0 ; i < NO_@@ OF_@@ CHARS ; i ++ ) { if ( ( count [ i ] & 1'
# ====================================================================================================
#
#
#
#
#
#
# ====================================================================================================
# SOURCE: 'bool is@@ Even ( int n ) { return ( ! ( n & 1 ) ) ; }'
# GENERATED: 'static boolean is@@ Even ( int n ) { return ( ( n & 1 )'
#
# ----------------------------------------------------------------------------------------------------
#
# NEXT TC TARGET: '!='
# PREDICTIONS: ['==', '==', '==', '==', '>']
# DISTANCES: [721 729 748 765 768]
#
# ----------------------------------------------------------------------------------------------------
#
# INPUT SOURCE: 'bool can@@ Form@@ Pal@@ ind@@ ro@@ me ( string str ) { int count [ NO_@@ OF_@@ CHARS ] = { 0 } ; for ( int i = 0 ; str [ i ] ; i ++ ) count [ str [ i ] ] ++ ; int odd = 0 ; for ( int i = 0 ; i < NO_@@ OF_@@ CHARS ; i ++ ) { if ( count [ i ] & 1 ) odd ++ ; if ( odd > 1 ) return false ; } return true ; } </s>'
# INPUT TARGET: 'static boolean can@@ Form@@ Pal@@ ind@@ ro@@ me ( String str ) { int count [ ] = new int [ NO_@@ OF_@@ CHARS ] ; Arrays . fill ( count , 0 ) ; for ( int i = 0 ; i < str . length ( ) ; i ++ ) count [ ( int ) ( str . charAt ( i ) ) ] ++ ; int odd = 0 ; for ( int i = 0 ; i < NO_@@ OF_@@ CHARS ; i ++ ) { if ( ( count [ i ] & 1 )'
# ====================================================================================================
#
#
#
#
#
#
# ====================================================================================================
# SOURCE: 'bool is@@ Even ( int n ) { return ( ! ( n & 1 ) ) ; }'
# GENERATED: 'static boolean is@@ Even ( int n ) { return ( ( n & 1 ) =='
#
# ----------------------------------------------------------------------------------------------------
#
# NEXT TC TARGET: '0'
# PREDICTIONS: ['0', '0', '0', '1', '1']
# DISTANCES: [633 710 717 736 747]
#
# ----------------------------------------------------------------------------------------------------
#
# INPUT SOURCE: 'unsigned int next@@ PowerOf@@ 2 ( unsigned int n ) { unsigned count = 0 ; if ( n && ! ( n & ( n - 1 ) ) ) return n ; while ( n != 0 ) { n >>= 1 ; count += 1 ; } return 1 << count ; } </s>'
# INPUT TARGET: 'static int next@@ PowerOf@@ 2 ( int n ) { int count = 0 ; if ( n > 0 && ( n & ( n - 1 ) ) =='
# ====================================================================================================
#
#
#
#
#
#
# ====================================================================================================
# SOURCE: 'bool is@@ Even ( int n ) { return ( ! ( n & 1 ) ) ; }'
# GENERATED: 'static boolean is@@ Even ( int n ) { return ( ( n & 1 ) == 0'
#
# ----------------------------------------------------------------------------------------------------
#
# NEXT TC TARGET: ')'
# PREDICTIONS: [')', ')', ')', ')', ')']
# DISTANCES: [591 612 628 654 658]
#
# ----------------------------------------------------------------------------------------------------
#
# INPUT SOURCE: 'int check ( string str ) { int n = str . length ( ) ; int digit@@ Sum = 0 ; for ( int i = 0 ; i < n ; i ++ ) digit@@ Sum += ( str [ i ] - '0' ) ; return ( digit@@ Sum % 3 == 0 ) ; } </s>'
# INPUT TARGET: 'static boolean check ( String str ) { int n = str . length ( ) ; int digit@@ Sum = 0 ; for ( int i = 0 ; i < n ; i ++ ) digit@@ Sum += ( str . charAt ( i ) - '0' ) ; return ( digit@@ Sum % 3 == 0'
# ====================================================================================================
#
#
#
#
#
#
# ====================================================================================================
# SOURCE: 'bool is@@ Even ( int n ) { return ( ! ( n & 1 ) ) ; }'
# GENERATED: 'static boolean is@@ Even ( int n ) { return ( ( n & 1 ) == 0 )'
#
# ----------------------------------------------------------------------------------------------------
#
# NEXT TC TARGET: ';'
# PREDICTIONS: [';', ';', ';', ';', ';']
# DISTANCES: [523 550 557 586 600]
#
# ----------------------------------------------------------------------------------------------------
#
# INPUT SOURCE: 'int check ( string str ) { int n = str . length ( ) ; int digit@@ Sum = 0 ; for ( int i = 0 ; i < n ; i ++ ) digit@@ Sum += ( str [ i ] - '0' ) ; return ( digit@@ Sum % 3 == 0 ) ; } </s>'
# INPUT TARGET: 'static boolean check ( String str ) { int n = str . length ( ) ; int digit@@ Sum = 0 ; for ( int i = 0 ; i < n ; i ++ ) digit@@ Sum += ( str . charAt ( i ) - '0' ) ; return ( digit@@ Sum % 3 == 0 )'
# ====================================================================================================
#
#
#
#
#
#
# ====================================================================================================
# SOURCE: 'bool is@@ Even ( int n ) { return ( ! ( n & 1 ) ) ; }'
# GENERATED: 'static boolean is@@ Even ( int n ) { return ( ( n & 1 ) == 0 ) ;'
#
# ----------------------------------------------------------------------------------------------------
#
# NEXT TC TARGET: '}'
# PREDICTIONS: ['}', '}', '}', '}', '}']
# DISTANCES: [103 105 105 106 106]
#
# ----------------------------------------------------------------------------------------------------
#
# INPUT SOURCE: 'bool check@@ Origin ( int x1 , int y1 , int x2 , int y2 ) { return ( x1 * ( y2 - y1 ) == y1 * ( x2 - x1 ) ) ; } </s>'
# INPUT TARGET: 'static boolean check@@ Origin ( int x1 , int y1 , int x2 , int y2 ) { return ( x1 * ( y2 - y1 ) == y1 * ( x2 - x1 ) ) ;'
# ====================================================================================================
#
#
#
#
#
#
# ====================================================================================================
# SOURCE: 'bool is@@ Even ( int n ) { return ( ! ( n & 1 ) ) ; }'
# GENERATED: 'static boolean is@@ Even ( int n ) { return ( ( n & 1 ) == 0 ) ; }'
#
# ----------------------------------------------------------------------------------------------------
#
# NEXT TC TARGET: '</s>'
# PREDICTIONS: ['</s>', '</s>', '</s>', '</s>', '</s>']
# DISTANCES: [82 82 84 84 85]
#
# ----------------------------------------------------------------------------------------------------
#
# INPUT SOURCE: 'long multiply@@ By@@ Se@@ ven ( long n ) { return ( ( n << 3 ) - n ) ; } </s>'
# INPUT TARGET: 'static int multiply@@ By@@ Se@@ ven ( int n ) { return ( ( n << 3 ) - n ) ; }'
# ====================================================================================================
#
#
#
#
#
#
# TC PREDICTION: 'public boolean is@@ Even ( int n ) { return ( ! n & 1 ) != 0 ) ; } </s>'
# FINAL PREDICTION: 'static boolean is@@ Even ( int n ) { return ( ( n & 1 ) == 0 ) ; } </s>'
# GROUND TRUTH: 'public static boolean is@@ Even ( int n ) { if ( ( n & 1 ) == 0 ) return true ; else return false ; } </s>'
